# %% [markdown]
# # Temporal Modeling
#
# Build patient-history features using prior encounters only.

# %%
from src.preprocess import load_and_prepare_data
from src.temporal_features import add_temporal_features
df=load_and_prepare_data("data/raw/diabetic_data.csv")
add_temporal_features(df).head()

# %% [markdown]
# # Costs and Workflow
#
# Tune the operating threshold and simulate care-team capacity.

# %%
import pandas as pd
from src.cost_sensitive import optimize_threshold
from src.workflow_simulation import run_workflow_scenarios
df=pd.read_csv("outputs/tables/test_scored.csv")
best,table=optimize_threshold(df["target"], df["risk_score"])
best, run_workflow_scenarios(df)

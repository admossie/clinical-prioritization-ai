# %% [markdown]
# # Calibration and Fairness
#
# Evaluate probability calibration and subgroup consistency.

# %%
import pandas as pd
from src.calibration import calibration_table
from src.fairness import run_fairness_suite
df=pd.read_csv("outputs/tables/test_scored.csv")
calibration_table(df["target"], df["risk_score"]).head(), run_fairness_suite(df)

# %% [markdown]
# # External Validation
#
# Score a mapped external dataset and save transportability metrics.

# %%
import joblib, pandas as pd
from src.external_validate import evaluate_external
model=joblib.load("models/best_model.joblib")
preprocessor=joblib.load("models/preprocessor.joblib")
df=pd.read_csv("data/external/sample_mimic_like.csv")
metrics,_=evaluate_external(model, preprocessor, df)
metrics
